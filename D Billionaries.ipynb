# %%
! dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9CB9-E181
#
#  Directory of C:\Mod5-Statistics\datas
#
# 10/16/2023  11:49 AM    <DIR>          .
# 10/16/2023  11:49 AM    <DIR>          ..
# 10/16/2023  10:57 AM    <DIR>          .ipynb_checkpoints
# 08/21/2023  08:30 PM           322,026 airlines.csv
# 08/22/2023  09:08 AM               361 anagrams.csv
# 08/22/2023  09:09 AM               556 anscombe.csv
# 10/15/2023  12:31 PM    <DIR>          archive (10)
# 10/15/2023  12:33 PM    <DIR>          archive (13)
# 10/15/2023  12:28 PM    <DIR>          archive (2)
# 10/15/2023  12:30 PM    <DIR>          archive (3)
# 10/15/2023  12:30 PM    <DIR>          archive (4)
# 10/15/2023  12:30 PM    <DIR>          archive (5)
# 10/15/2023  12:30 PM    <DIR>          archive (6)
# 10/15/2023  12:30 PM    <DIR>          archive (7)
# 10/15/2023  12:30 PM    <DIR>          archive (8)
# 10/15/2023  12:30 PM    <DIR>          archive (9)
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %%
Bdata = pd.read_csv("Billionaires Statistics Dataset.csv.xls",index_col="rank")
Bdata
# Out:
#       finalWorth               category                personName   age  \
# rank
# 1         211000       Fashion & Retail  Bernard Arnault & family  74.0
# 2         180000             Automotive                 Elon Musk  51.0
# 3         114000             Technology                Jeff Bezos  59.0
# 4         107000             Technology             Larry Ellison  78.0
# 5         106000  Finance & Investments            Warren Buffett  92.0
# ...          ...                    ...                       ...   ...
# 2540        1000             Healthcare                   Yu Rong  51.0
# 2540        1000        Food & Beverage    Richard Yuengling, Jr.  80.0
# 2540        1000          Manufacturing             Zhang Gongyun  60.0
# 2540        1000            Real Estate    Zhang Guiping & family  71.0
# 2540        1000            Diversified               Inigo Zobel  66.0
#
#             country        city                        source  \
# rank
# ...

# %%
Bdata.columns
# Out:
# Index(['finalWorth', 'category', 'personName', 'age', 'country', 'city',
#        'source', 'industries', 'countryOfCitizenship', 'organization',
#        'selfMade', 'status', 'gender', 'birthDate', 'lastName', 'firstName',
#        'title', 'date', 'state', 'residenceStateRegion', 'birthYear',
#        'birthMonth', 'birthDay', 'cpi_country', 'cpi_change_country',
#        'gdp_country', 'gross_tertiary_education_enrollment',
#        'gross_primary_education_enrollment_country', 'life_expectancy_country',
#        'tax_revenue_country_country', 'total_tax_rate_country',
#        'population_country', 'latitude_country', 'longitude_country'],
#       dtype='object')

# %%
Bdata.shape
# Out:
# (2640, 34)

# %%
Bdata.size
# Out:
# 89760

# %%
Bdata.isnull().sum()
# Out:
# finalWorth                                       0
# category                                         0
# personName                                       0
# age                                              0
# country                                         38
# city                                            72
# source                                           0
# industries                                       0
# countryOfCitizenship                             0
# organization                                  2315
# selfMade                                         0
# status                                           0
# gender                                           0
# birthDate                                       76
# lastName                                         0
# firstName                                        3
# title                                         2301
# date                                             0
# ...

# %%
Bdata["age"].fillna(Bdata["age"].mode()[0],inplace=True)

# %%
Bdata.groupby("country")

# %%
Bdata["country"].value_counts()
# Out:
# United States           754
# China                   523
# India                   157
# Germany                 102
# United Kingdom           82
#                        ...
# Portugal                  1
# Georgia                   1
# Eswatini (Swaziland)      1
# Uzbekistan                1
# Armenia                   1
# Name: country, Length: 78, dtype: int64

# %%
ctgry_grp = Bdata.groupby("category")

# %%
Bdata["country"].value_counts()
# Out:
# United States           754
# China                   523
# India                   157
# Germany                 102
# United Kingdom           82
#                        ...
# Portugal                  1
# Georgia                   1
# Eswatini (Swaziland)      1
# Uzbekistan                1
# Armenia                   1
# Name: country, Length: 78, dtype: int64

# %%
Bdata["city"].value_counts()
# Out:
# New York       99
# Beijing        68
# Hong Kong      68
# Shanghai       64
# London         61
#                ..
# Küsnacht        1
# Brownsville     1
# Montpellier     1
# Santa Clara     1
# Makati          1
# Name: city, Length: 741, dtype: int64

# %%
Bdata["category"].unique()
# Out:
# array(['Fashion & Retail', 'Automotive', 'Technology',
#        'Finance & Investments', 'Media & Entertainment', 'Telecom',
#        'Diversified', 'Food & Beverage', 'Logistics',
#        'Gambling & Casinos', 'Manufacturing', 'Real Estate',
#        'Metals & Mining', 'Energy', 'Healthcare', 'Service',
#        'Construction & Engineering', 'Sports'], dtype=object)

# %%
Bdata["category"].value_counts()
# Out:
# Finance & Investments         372
# Manufacturing                 324
# Technology                    314
# Fashion & Retail              266
# Food & Beverage               212
# Healthcare                    201
# Real Estate                   193
# Diversified                   187
# Energy                        100
# Media & Entertainment          91
# Metals & Mining                74
# Automotive                     73
# Service                        53
# Construction & Engineering     45
# Logistics                      40
# Sports                         39
# Telecom                        31
# Gambling & Casinos             25
# Name: category, dtype: int64

# %%
fashion_df = pd.DataFrame(ctgry_grp.get_group("Fashion & Retail"))
fashion_df
# Out:
#       finalWorth          category                             personName  \
# rank
# 1         211000  Fashion & Retail               Bernard Arnault & family
# 11         80500  Fashion & Retail  Francoise Bettencourt Meyers & family
# 13         77300  Fashion & Retail                         Amancio Ortega
# 19         58800  Fashion & Retail                             Jim Walton
# 20         57600  Fashion & Retail                    Rob Walton & family
# ...          ...               ...                                    ...
# 2540        1000  Fashion & Retail                        Johan Johannson
# 2540        1000  Fashion & Retail                         Kim Jung-woong
# 2540        1000  Fashion & Retail                             Liu Baolin
# 2540        1000  Fashion & Retail                           Réal Plourde
# 2540        1000  Fashion & Retail                 Xie Bingzheng & family
#
# ...

# %%
fashion_df.nunique()
# Out:
# finalWorth                                     82
# category                                        1
# personName                                    266
# age                                            64
# country                                        37
# city                                          151
# source                                         98
# industries                                      1
# countryOfCitizenship                           36
# organization                                   29
# selfMade                                        2
# status                                          6
# gender                                          2
# birthDate                                     243
# lastName                                      204
# firstName                                     234
# title                                          18
# date                                            1
# state                                          23
# ...

# %%
finance_df = pd.DataFrame(ctgry_grp.get_group("Finance & Investments"))
finance_df
# Out:
#       finalWorth               category          personName   age  \
# rank
# 5         106000  Finance & Investments      Warren Buffett  92.0
# 35         35000  Finance & Investments         Ken Griffin  54.0
# 48         28500  Finance & Investments           Jeff Yass  64.0
# 49         28100  Finance & Investments          Jim Simons  84.0
# 50         27800  Finance & Investments  Stephen Schwarzman  76.0
# ...          ...                    ...                 ...   ...
# 2540        1000  Finance & Investments         Lev Kvetnoi  57.0
# 2540        1000  Finance & Investments     Michiel Le Roux  73.0
# 2540        1000  Finance & Investments       Stanley Motta  77.0
# 2540        1000  Finance & Investments    Sergei Sudarikov  51.0
# 2540        1000  Finance & Investments       V. Prem Watsa  72.0
#
#             country           city                  source  \
# rank
# 5     United States          Omaha      Berkshire Hathaway
# ...

# %%
Bdata[Bdata.loc[:,:]].max()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 Bdata[Bdata.loc[:,:]].max()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:3794, in DataFrame.__getitem__(self, key)
#    3792 # Do we have a (boolean) DataFrame?
#    3793 if isinstance(key, DataFrame):
# -> 3794     return self.where(key)
#    3796 # Do we have a (boolean) 1d indexer?
#    3797 if com.is_bool_indexer(key):
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
finalWorth = Bdata["finalWorth"].var()
print("Variance of finalWorth",finalWorth)
# Out:
# Variance of finalWorth 96712294.85457094

# %%
total_tax_rate_country = Bdata["total_tax_rate_country"].var()
print("Variance of total_tax_rate_country",total_tax_rate_country)
# Out:
# Variance of total_tax_rate_country 147.50820810371462
